# %% [markdown]
# <a href="https://maestriasydiplomados.tec.mx/posgrados/maestria-en-inteligencia-artificial-aplicada"><img src="logo_MR4010.png"></a>
# <h1> <div align="center"> Dr. David Antonio-Torres</div> </h1>

# %% [markdown]
# # Demostración de Kera Application

# %% [markdown]
# # Se cargan las bibliotecas necesarias

# %%
import PIL
import tensorflow as tf
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from keras.applications.imagenet_utils import decode_predictions 
import matplotlib.pyplot as plt 
import numpy as np 
from keras.applications.resnet import ResNet50
# %matplotlib inline

# %%
filename = 'peacock.jpg' 
## load an image in PIL format 
original = load_img(filename, target_size = (224, 224)) 
print('PIL image size',original.size)
plt.imshow(original) 
plt.show()
# Out:
# PIL image size (224, 224)

# %%
#convert the PIL image to a numpy array 
numpy_image = img_to_array(original) 

plt.imshow(np.uint8(numpy_image)) 

print('numpy array size',numpy_image.shape) 

# Convert the image / images into batch format 
image_batch = np.expand_dims(numpy_image, axis = 0) 

print('image batch size', image_batch.shape)
# Out:
# numpy array size (224, 224, 3)
# image batch size (1, 224, 224, 3)

# %%
#processed_image = ResNet50.preprocess_input(image_batch.copy()) 
processed_image = tf.keras.applications.resnet50.preprocess_input(image_batch.copy())

# create resnet model 
resnet_model = ResNet50(weights = 'imagenet') 

# get the predicted probabilities for each class 
predictions = resnet_model.predict(processed_image) 

# convert the probabilities to class labels 
label = decode_predictions(predictions) 

print(label)
# Out:
# 1/1 [==============================] - 1s 950ms/step
# [[('n01806143', 'peacock', 0.9995116), ('n02017213', 'European_gallinule', 0.00019161004), ('n01847000', 'drake', 0.00011351371), ('n01514668', 'cock', 3.6598827e-05), ('n01795545', 'black_grouse', 3.6351572e-05)]]
